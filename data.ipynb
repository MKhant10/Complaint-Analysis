# %%
import pandas as pd

# %%
df = pd.read_csv('data/complaints.csv')
df.head()
# Out:
#   Date received                                            Product  \
# 0    2020-07-06  Credit reporting, credit repair services, or o...
# 1    2019-12-26                        Credit card or prepaid card
# 2    2020-05-08  Credit reporting, credit repair services, or o...
# 3    2024-01-05  Credit reporting or other personal consumer re...
# 4    2024-01-21  Credit reporting or other personal consumer re...
#
#                                   Sub-product  \
# 0                            Credit reporting
# 1  General-purpose credit card or charge card
# 2                            Credit reporting
# 3                            Credit reporting
# 4                            Credit reporting
#
#                                                Issue  \
# 0               Incorrect information on your report
# 1  Advertising and marketing, including promotion...
# 2               Incorrect information on your report
# 3               Incorrect information on your report
# 4                        Improper use of your report
#
#                                            Sub-issue  \
# 0                Information belongs to someone else
# 1  Confusing or misleading advertising about the ...
# 2                Information belongs to someone else
# 3                Information belongs to someone else
# 4  Credit inquiries on your report that you don't...
#
#                         Consumer complaint narrative  \
# 0                                                NaN
# 1                                                NaN
# 2                         These are not my accounts.
# 3  Kindly address this issue on my credit report....
# 4                                                NaN
#
#                              Company public response  \
# 0  Company has responded to the consumer and the ...
# 1                                                NaN
# 2  Company has responded to the consumer and the ...
# 3  Company has responded to the consumer and the ...
# 4  Company has responded to the consumer and the ...
#
#                                Company State ZIP code           Tags  \
# 0  Experian Information Solutions Inc.    FL    346XX            NaN
# 1    CAPITAL ONE FINANCIAL CORPORATION    CA    94025            NaN
# 2  Experian Information Solutions Inc.    NV    89030            NaN
# 3  Experian Information Solutions Inc.    IL    60502            NaN
# 4  Experian Information Solutions Inc.    NC    27401  Servicemember
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                      Other           Web           2020-07-06
# 1       Consent not provided           Web           2019-12-26
# 2           Consent provided           Web           2020-05-08
# 3           Consent provided           Web           2024-01-05
# 4       Consent not provided           Web           2024-01-21
#
#       Company response to consumer Timely response? Consumer disputed?  \
# 0          Closed with explanation              Yes                NaN
# 1          Closed with explanation              Yes                NaN
# 2          Closed with explanation              Yes                NaN
# 3  Closed with non-monetary relief              Yes                NaN
# 4          Closed with explanation              Yes                NaN
#
#    Complaint ID
# 0       3730948
# 1       3477549
# 2       3642453
# 3       8113747
# 4       8191825

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15188499 entries, 0 to 15188498
# Data columns (total 18 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Date received                 str
#  1   Product                       str
#  2   Sub-product                   str
#  3   Issue                         str
#  4   Sub-issue                     str
#  5   Consumer complaint narrative  str
#  6   Company public response       str
#  7   Company                       str
#  8   State                         str
#  9   ZIP code                      str
#  10  Tags                          str
#  11  Consumer consent provided?    str
#  12  Submitted via                 str
#  13  Date sent to company          str
#  14  Company response to consumer  str
#  15  Timely response?              str
#  16  Consumer disputed?            str
#  17  Complaint ID                  int64
# dtypes: int64(1), str(17)
# memory usage: 2.0 GB

# %%
data = df[['Product', 'Consumer complaint narrative']]

# %%
data = data.rename(columns={'Consumer complaint narrative': 'complaints', 'Product': 'product'})

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15188499 entries, 0 to 15188498
# Data columns (total 2 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   product     str
#  1   complaints  str
# dtypes: str(2)
# memory usage: 231.8 MB

# %%
data.head()
# Out:
#                                              product  \
# 0  Credit reporting, credit repair services, or o...
# 1                        Credit card or prepaid card
# 2  Credit reporting, credit repair services, or o...
# 3  Credit reporting or other personal consumer re...
# 4  Credit reporting or other personal consumer re...
#
#                                           complaints
# 0                                                NaN
# 1                                                NaN
# 2                         These are not my accounts.
# 3  Kindly address this issue on my credit report....
# 4                                                NaN

# %%
data.isnull().sum()
# Out:
# product              0
# complaints    11407901
# dtype: int64

# %% [markdown]
# # Rename Product
# - credit_reporting
# - mortgage
# - credit_card
# - retail_banking
# - loans
# - debt_collection

# %%
data["product"].value_counts()
# Out:
# product
# Credit reporting or other personal consumer reports                             9844643
# Credit reporting, credit repair services, or other personal consumer reports    2163800
# Debt collection                                                                 1089888
# Mortgage                                                                         448259
# Checking or savings account                                                      364460
# Credit card                                                                      310916
# Credit card or prepaid card                                                      206364
# Money transfer, virtual currency, or money service                               177943
# Credit reporting                                                                 140426
# Student loan                                                                     126633
# Vehicle loan or lease                                                             94437
# Bank account or service                                                           86200
# Consumer Loan                                                                     31559
# Payday loan, title loan, personal loan, or advance loan                           30721
# Payday loan, title loan, or personal loan                                         30625
# Prepaid card                                                                      20948
# Debt or credit management                                                          8721
# Payday loan                                                                        5528
# Money transfers                                                                    5354
# Other financial service                                                            1056
# Virtual currency                                                                     18
# Name: count, dtype: int64

# %%
data["product"] = data["product"].replace(
    {
        "Credit reporting or other personal consumer reports": "credit_reporting",
        "Credit reporting, credit repair services, or other personal consumer reports": "credit_reporting",
        "Debt collection" : "debt_collection",
        "Mortgage" : "mortgage",
        "Checking or savings account": "retail_banking",
        "Credit card" : "credit_card",
        "Credit card or prepaid card" : "credit_card",
        "Money transfer, virtual currency, or money service": "retail_banking",
        "Credit reporting": "credit_reporting",
        "Student loan": "loans",
        "Vehicle loan or lease": "loans",
        "Bank account or service": "retail_banking",
        "Consumer Loan": "loans",
        "Payday loan, title loan, personal loan, or advance loan": "loans",
        "Payday loan, title loan, or personal loan": "loans",
        "Prepaid card": "credit_card",
        "Debt or credit management": "retail_banking",
        "Payday loan": "loans",
        "Money transfers": "retail_banking",
        "Other financial service": "retail_banking",
        "Virtual currency": "retail_banking"
    }
)

# %%
data["product"].value_counts()
# Out:
# product
# credit_reporting    12148869
# debt_collection      1089888
# retail_banking        643752
# credit_card           538228
# mortgage              448259
# loans                 319503
# Name: count, dtype: int64

# %%
data.to_csv('data/product_complaints.csv', index=False)
